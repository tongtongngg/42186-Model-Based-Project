# %%
import pandas as pd
data = pd.read_csv("premier_league.csv", encoding='latin1')
print(data)

print(data.info())
# Out:
#            player_name      team_name position  accurateCrosses  \
# 0          Declan Rice        Arsenal        M               41
# 1    Gabriel Magalhães        Arsenal        D                1
# 2          Bukayo Saka        Arsenal        F               36
# 3     Martín Zubimendi        Arsenal        M                2
# 4           Max Dowman        Arsenal        M                0
# ..                 ...            ...      ...              ...
# 512     Tolu Arokodare  Wolverhampton        F                0
# 513          Fer López  Wolverhampton        M                1
# 514       Matt Doherty  Wolverhampton        D                2
# 515         Toti Gomes  Wolverhampton        D                3
# 516     Saa Kalajdi?  Wolverhampton        F                0
#
#      accurateCrossesPercentage  accurateFinalThirdPasses  accurateLongBalls  \
# 0                    28.082192                       459                 72
# ...
